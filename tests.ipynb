# %%
import pandas as pd

data = pd.read_csv("performance_survey_cleaned.csv")
data.head()
# Out:
#    condition    wer  num_signgloss  \
# 0          1  0.111              9
# 1          1  0.167              6
# 2          1  0.091             11
# 3          1  0.000              3
# 4          1  0.077             13
#
#                                     intended_meaning  \
# 0  My family is small. It consists of my mother, ...
# 1        My family has a total of six grandchildren.
# 2  My family recently moved to New York City beca...
# 3                We are fine with the family moving.
# 4  My family vacation every year is in Florida be...
#
#                                            asl_gloss  \
# 0  MY FAMILY SMALL MOTHER FATHER YOUNG SISTER I F...
# 1            MY FAMILY HAVE TOTAL SIX GRANDCHILDREN
# 2  FAMILY MOVE RECENT WHERE NYC WHY FATHER THERE ...
# 3                                FAMILY MOVE WE FINE
# 4  MY FAMILY VACATION TOGETHER EVERY-YEAR WHERE T...
#
#                                      error_asl_gloss  \
# ...

# %%
condition = 1
cond_data = data[data["condition"] == condition]

cond_data.head()
# Out:
#    condition    wer  num_signgloss  \
# 0          1  0.111              9
# 1          1  0.167              6
# 2          1  0.091             11
# 3          1  0.000              3
# 4          1  0.077             13
#
#                                     intended_meaning  \
# 0  My family is small. It consists of my mother, ...
# 1        My family has a total of six grandchildren.
# 2  My family recently moved to New York City beca...
# 3                We are fine with the family moving.
# 4  My family vacation every year is in Florida be...
#
#                                            asl_gloss  \
# 0  MY FAMILY SMALL MOTHER FATHER YOUNG SISTER I F...
# 1            MY FAMILY HAVE TOTAL SIX GRANDCHILDREN
# 2  FAMILY MOVE RECENT WHERE NYC WHY FATHER THERE ...
# 3                                FAMILY MOVE WE FINE
# 4  MY FAMILY VACATION TOGETHER EVERY-YEAR WHERE T...
#
#                                      error_asl_gloss  \
# ...

# %%
index = 1
row = cond_data.iloc[index]
row["intended_meaning"]
# Out:
# 'My family has a total of six grandchildren.'

# %%
conditions_used = [3, 5, 9]
form_factors = ["glasses", "glasses + glove", "glasses + ring", "glasses + wristband"]
incomplete_conditions = [(c, f) for c in conditions_used for f in form_factors]

# %%
incomplete_conditions.remove((3, "glasses"))
incomplete_conditions
# Out:
# [(3, 'glasses + glove'),
#  (3, 'glasses + ring'),
#  (3, 'glasses + wristband'),
#  (5, 'glasses'),
#  (5, 'glasses + glove'),
#  (5, 'glasses + ring'),
#  (5, 'glasses + wristband'),
#  (9, 'glasses'),
#  (9, 'glasses + glove'),
#  (9, 'glasses + ring'),
#  (9, 'glasses + wristband')]
